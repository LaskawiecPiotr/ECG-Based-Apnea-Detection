# %%
# import all the relevant libraries
import wfdb
import mne
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, hamming_loss
from sklearn.pipeline import make_pipeline,Pipeline
from sklearn.preprocessing import FunctionTransformer,StandardScaler
from mne.datasets import sample
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, KFold
from mne_features.feature_extraction import extract_features
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest,f_classif
# Out:
# C:\Users\piotr\anaconda_projects\anaconda3\Lib\site-packages\mne_features\mock_numba.py:12: UserWarning: Numba needs NumPy 2.0 or less. Got NumPy 2.2.. Your code will be slower.
#   warn('{}. Your code will be slower.'.format(err))

# %%
# This function takes in the record path of a PSG file and outputs the epochs. It renames, changes types and removes channels so that they
# are consistent between different patients. Some patients had more/less data collected through different manners which had to be fixed.
def create_epoch(record_path):
    record = wfdb.rdrecord(record_path)
    annotation = wfdb.rdann(record_path, 'st')
    
    annotation_mne = mne.Annotations(
        onset=annotation.sample / record.fs,
        duration=30,
        description=annotation.aux_note
    )
    
    signals = record.p_signal  # Signal data as NumPy array
    sampling_rate = record.fs  # Sampling frequency (e.g., 250 Hz)
    channel_names = record.sig_name  # Channel names
    seen_categories = set()
    
    # Assign types while ensuring only the first occurrence is assigned correctly
    channel_types = []
    channel_names_updated = []
    
    for ch in channel_names:
        if "EEG" in ch and "EEG" not in seen_categories:
            channel_types.append("eeg")
            channel_names_updated.append("EEG")
            seen_categories.add("EEG")
        elif "Resp" in ch and "Resp" not in seen_categories:
            channel_types.append("resp")
            channel_names_updated.append("Respiratory")
            seen_categories.add("Resp")
        elif "ECG" in ch and "ECG" not in seen_categories:
            channel_types.append("ecg")
            channel_names_updated.append("ECG")
            seen_categories.add("ECG")
        else:
            channel_types.append("misc")
            channel_names_updated.append(ch)
    # Create MNE Info object
    info = mne.create_info(
        ch_names=channel_names_updated,
        sfreq=sampling_rate,
        ch_types=channel_types
    )
    # Convert signals to MNE RawArray
    raw = mne.io.RawArray(signals.T, info)
    
    # Add annotations to the raw object
    raw.set_annotations(annotation_mne)
    misc_channels = [ch for ch, ch_type in zip(channel_names_updated, channel_types) if "misc" in ch_type]
    raw.drop_channels(misc_channels)
    event_labels = {
    1: "Hypopnea",
    2: "Obstructive Apnea",
    3: "Central Apnea",
    4: "No Apnea Event"
    }
    new_id = {}
    for desc in raw.annotations.description:
        if "H" in desc or "HA" in desc:  # Hypopnea
            new_id[desc] = 1
        elif " A" in desc or "X" in desc:  # Obstructive Apnea
            new_id[desc] = 2
        elif "CA" in desc or "CAA" in desc:  # Central Apnea
            new_id[desc] = 3
        else:  # Other
            new_id[desc] = 4
    
    # Generate events with the new mapping
    events, event_id = mne.events_from_annotations(raw, event_id=new_id)
    
    new_annotations = mne.Annotations(
        onset=events[:, 0] / raw.info["sfreq"],  # Convert sample index to seconds
        duration=[30] * len(events),  # Assume each event lasts 30 seconds
        description=[event_labels[e] for e in events[:, 2]]  # Convert IDs back to labels
    )
    tmax = 30.0 - 1.0 / raw.info["sfreq"]  # tmax in included
    epochs = mne.Epochs(
        raw,
        events=events,
        tmin=0.0,
        tmax=tmax,
        baseline=None,
        picks=["ECG",'Respiratory',"EEG"]
    )
    return epochs

# %%
all_epochs=[]
List_of_subjects=open(r"\Users\piotr\Desktop\PSG data\List of subjects.txt","r").read().split("\n")
for i in List_of_subjects:
    record_path = fr"C:\Users\piotr\Desktop\PSG data\MIT Data\{i}"
    all_epochs.append(create_epoch(record_path))
# Out:
# Creating RawArray with float64 data, n_channels=4, n_times=1800000
#     Range : 0 ... 1799999 =      0.000 ...  7199.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1 LA'), np.str_('2'), np.str_('2 H'), np.str_('2 H H'), np.str_('2 H LA'), np.str_('2 HA'), np.str_('2 L'), np.str_('2 L HA'), np.str_('2 L LA'), np.str_('2 LA'), np.str_('2 LA H'), np.str_('2 LA HA'), np.str_('2 LA L'), np.str_('2 LA LA'), np.str_('3'), np.str_('3 H'), np.str_('3 H LA'), np.str_('3 HA'), np.str_('3 L'), np.str_('3 L HA LA'), np.str_('3 L L'), np.str_('3 L LA'), np.str_('3 LA'), np.str_('3 LA L'), np.str_('3 LA LA'), np.str_('4'), np.str_('4 L'), np.str_('4 L L'), np.str_('4 L L L'), np.str_('4 L LA'), np.str_('4 LA'), np.str_('4 LA HA LA'), np.str_('4 LA L'), np.str_('4 LA LA'), np.str_('MT'), np.str_('R'), np.str_('R H'), np.str_('R HA'), np.str_('W'), np.str_('W HA'), np.str_('W LA')]
# Not setting metadata
# 240 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=4, n_times=2700000
#     Range : 0 ... 2699999 =      0.000 ... 10799.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 CA'), np.str_('1 CAA'), np.str_('1 H'), np.str_('1 HA'), np.str_('2'), np.str_('2 CAA'), np.str_('2 H'), np.str_('2 H HA'), np.str_('2 HA'), np.str_('2 L'), np.str_('2 LA'), np.str_('2 X'), np.str_('R'), np.str_('R H'), np.str_('R L'), np.str_('R LA'), np.str_('W'), np.str_('W H'), np.str_('W HA'), np.str_('W L'), np.str_('W LA')]
# Not setting metadata
# 360 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=4, n_times=2700000
#     Range : 0 ... 2699999 =      0.000 ... 10799.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 A'), np.str_('1 L'), np.str_('1 X'), np.str_('2'), np.str_('2 H'), np.str_('2 L'), np.str_('2 L X'), np.str_('2 LA'), np.str_('2 X'), np.str_('2 X X'), np.str_('3'), np.str_('4'), np.str_('MT'), np.str_('MT X'), np.str_('R'), np.str_('R A'), np.str_('R H'), np.str_('R L'), np.str_('R X'), np.str_('W'), np.str_('W L'), np.str_('W X'), np.str_('W X X')]
# Not setting metadata
# 360 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=4, n_times=2025000
#     Range : 0 ... 2024999 =      0.000 ...  8099.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 A'), np.str_('1 A X'), np.str_('1 L'), np.str_('1 L L'), np.str_('1 X'), np.str_('2'), np.str_('2 A'), np.str_('2 L'), np.str_('2 L A'), np.str_('2 L L'), np.str_('2 L LA'), np.str_('2 LA'), np.str_('2 LA H'), np.str_('2 X'), np.str_('MT'), np.str_('R'), np.str_('R A'), np.str_('R L H'), np.str_('R OA'), np.str_('R X'), np.str_('W'), np.str_('W L'), np.str_('W LA'), np.str_('W X'), np.str_('W X X')]
# Not setting metadata
# 270 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=4, n_times=5400000
#     Range : 0 ... 5399999 =      0.000 ... 21599.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 CAA'), np.str_('1 CAA CAA'), np.str_('1 H'), np.str_('1 H H'), np.str_('1 HA'), np.str_('1 HA H'), np.str_('1 HA HA'), np.str_('1 L'), np.str_('1 L L'), np.str_('1 X'), np.str_('2'), np.str_('2 CA'), np.str_('2 CAA'), np.str_('2 H'), np.str_('2 H H'), np.str_('2 HA'), np.str_('2 HA H'), np.str_('2 HA HA'), np.str_('2 HA X'), np.str_('2 X'), np.str_('2 X H'), np.str_('3'), np.str_('3 H'), np.str_('3 H H'), np.str_('R'), np.str_('R CA'), np.str_('R H'), np.str_('R H CA'), np.str_('R H HA'), np.str_('R H X'), np.str_('R HA'), np.str_('R OA'), np.str_('R X'), np.str_('R X CA'), np.str_('R X H'), np.str_('R X OA'), np.str_('R X X'), np.str_('W'), np.str_('W HA'), np.str_('W X')]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=4, n_times=5400000
#     Range : 0 ... 5399999 =      0.000 ... 21599.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 A'), np.str_('1 L'), np.str_('1 X'), np.str_('1 X X'), np.str_('2'), np.str_('2 A'), np.str_('2 A A A'), np.str_('2 H'), np.str_('2 L'), np.str_('2 L X'), np.str_('2 LA'), np.str_('2 X'), np.str_('2 X A'), np.str_('2 X L'), np.str_('2 X X'), np.str_('3'), np.str_('3 A'), np.str_('3 L'), np.str_('3 X'), np.str_('R'), np.str_('R X'), np.str_('R X X'), np.str_('W'), np.str_('W X'), np.str_('W X X')]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=4, n_times=5400000
#     Range : 0 ... 5399999 =      0.000 ... 21599.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 H H'), np.str_('1 HA'), np.str_('1 LA'), np.str_('1 X'), np.str_('1 X X'), np.str_('2'), np.str_('2 H'), np.str_('2 HA'), np.str_('2 OA'), np.str_('2 X'), np.str_('3'), np.str_('4'), np.str_('MT'), np.str_('R'), np.str_('R HA'), np.str_('R X'), np.str_('W'), np.str_('W HA'), np.str_('W L'), np.str_('W X')]
# Not setting metadata
# 714 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=4, n_times=5400000
#     Range : 0 ... 5399999 =      0.000 ... 21599.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 CA'), np.str_('1 CAA'), np.str_('1 CAA HA'), np.str_('1 CAA X'), np.str_('1 H'), np.str_('1 HA'), np.str_('1 HA CA'), np.str_('1 HA HA'), np.str_('1 HA X'), np.str_('1 X'), np.str_('1 X X'), np.str_('2'), np.str_('2 CA'), np.str_('2 CAA'), np.str_('2 H'), np.str_('2 HA'), np.str_('2 X'), np.str_('2 X L'), np.str_('2 X X'), np.str_('3'), np.str_('4'), np.str_('R'), np.str_('R HA'), np.str_('R L'), np.str_('R LLLL LLL'), np.str_('R X'), np.str_('W'), np.str_('W CAA'), np.str_('W CAA HA'), np.str_('W HA'), np.str_('W HA HA'), np.str_('W HA X'), np.str_('W X'), np.str_('W X CAA'), np.str_('W X X')]
# Not setting metadata
# 694 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=7, n_times=4800000
#     Range : 0 ... 4799999 =      0.000 ... 19199.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 X'), np.str_('1 X L'), np.str_('2'), np.str_('2 H'), np.str_('2 L'), np.str_('2 L L'), np.str_('2 LA'), np.str_('2 LA L'), np.str_('2 OA'), np.str_('2 OA L'), np.str_('2 X'), np.str_('2 X L'), np.str_('3'), np.str_('3 X'), np.str_('4'), np.str_('4 X'), np.str_('W'), np.str_('W X')]
# Not setting metadata
# 640 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=7, n_times=5250000
#     Range : 0 ... 5249999 =      0.000 ... 20999.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 OA'), np.str_('1 OA OA'), np.str_('1 X'), np.str_('2'), np.str_('2 A'), np.str_('2 L'), np.str_('2 L A'), np.str_('2 L OA'), np.str_('2 LA'), np.str_('2 OA'), np.str_('2 OA OA'), np.str_('2 X'), np.str_('2 X OA'), np.str_('2 X X'), np.str_('R'), np.str_('R OA'), np.str_('R X'), np.str_('R X OA'), np.str_('W'), np.str_('W OA'), np.str_('W X')]
# Not setting metadata
# 698 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=7, n_times=5850000
#     Range : 0 ... 5849999 =      0.000 ... 23399.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('2'), np.str_('3'), np.str_('R'), np.str_('W')]
# Not setting metadata
# 780 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=7, n_times=5700000
#     Range : 0 ... 5699999 =      0.000 ... 22799.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('2'), np.str_('3'), np.str_('4'), np.str_('M'), np.str_('R'), np.str_('W')]
# Not setting metadata
# 760 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=7, n_times=5700000
#     Range : 0 ... 5699999 =      0.000 ... 22799.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 H'), np.str_('1 HA'), np.str_('1 HA CAA'), np.str_('1 HA HA'), np.str_('1 LA LA'), np.str_('1 LA X'), np.str_('1 X'), np.str_('2'), np.str_('2 H'), np.str_('2 HA'), np.str_('2 OA'), np.str_('2 X'), np.str_('3'), np.str_('MT'), np.str_('R'), np.str_('R H'), np.str_('W'), np.str_('W HA'), np.str_('W X')]
# Not setting metadata
# 760 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=7, n_times=3600000
#     Range : 0 ... 3599999 =      0.000 ... 14399.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 CA'), np.str_('1 CAA'), np.str_('1 CAA CAA'), np.str_('1 CAA HA'), np.str_('1 H'), np.str_('1 HA'), np.str_('1 HA CAA'), np.str_('1 HA L'), np.str_('1 HA X'), np.str_('1 L'), np.str_('1 LA'), np.str_('1 X'), np.str_('1 X L'), np.str_('1 X X'), np.str_('2'), np.str_('2 CA'), np.str_('2 CAA'), np.str_('2 H'), np.str_('2 HA'), np.str_('2 L'), np.str_('2 L H'), np.str_('2 LA'), np.str_('2 X'), np.str_('3'), np.str_('3 H'), np.str_('3 H CA'), np.str_('3 HA'), np.str_('3 L'), np.str_('3 LA'), np.str_('3 LL H'), np.str_('4'), np.str_('4 CA'), np.str_('4 CAA'), np.str_('4 H L'), np.str_('4 L'), np.str_('4 L H'), np.str_('4 LL'), np.str_('R'), np.str_('R CAA'), np.str_('R CAA L'), np.str_('R H'), np.str_('R HA'), np.str_('R L CAA'), np.str_('R OA'), np.str_('R X'), np.str_('W'), np.str_('W CAA'), np.str_('W HA'), np.str_('W HA X'), np.str_('W X')]
# Not setting metadata
# 458 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=7, n_times=5325000
#     Range : 0 ... 5324999 =      0.000 ... 21299.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 CA'), np.str_('1 CAA'), np.str_('1 CAA CAA'), np.str_('1 H'), np.str_('1 H X'), np.str_('1 HA'), np.str_('1 HA H'), np.str_('1 HA X'), np.str_('1 OA'), np.str_('1 OA X'), np.str_('1 X'), np.str_('1 X H'), np.str_('2'), np.str_('2 CAA'), np.str_('2 H'), np.str_('2 HA'), np.str_('2 OA'), np.str_('2 X'), np.str_('R'), np.str_('R HA'), np.str_('R L'), np.str_('R L LA'), np.str_('R LA'), np.str_('R LL'), np.str_('R X'), np.str_('W'), np.str_('W CA'), np.str_('W CAA'), np.str_('W CAA CAA'), np.str_('W HA'), np.str_('W HA X'), np.str_('W X')]
# Not setting metadata
# 710 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=6, n_times=5550000
#     Range : 0 ... 5549999 =      0.000 ... 22199.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 CA'), np.str_('1 CAA'), np.str_('1 H'), np.str_('1 H X'), np.str_('1 L L'), np.str_('1 OA'), np.str_('1 X'), np.str_('2'), np.str_('2 CA'), np.str_('2 CAA'), np.str_('2 H'), np.str_('2 H L'), np.str_('2 L'), np.str_('2 LA'), np.str_('2 LL'), np.str_('2 OA'), np.str_('2 X'), np.str_('2 X L'), np.str_('3'), np.str_('3 CAA'), np.str_('3 H'), np.str_('3 L'), np.str_('3 L LA'), np.str_('3 LA'), np.str_('3 LA LA'), np.str_('3 OA'), np.str_('3 X'), np.str_('3 X L'), np.str_('3 X LA'), np.str_('R'), np.str_('R H'), np.str_('R L'), np.str_('R LA'), np.str_('R OA'), np.str_('R X'), np.str_('W'), np.str_('W OA'), np.str_('W X')]
# Not setting metadata
# 720 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=7, n_times=3300000
#     Range : 0 ... 3299999 =      0.000 ... 13199.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 H'), np.str_('1 H H'), np.str_('1 H HA'), np.str_('1 HA'), np.str_('1 HA HA'), np.str_('1 X'), np.str_('1 X H'), np.str_('2'), np.str_('2 H'), np.str_('2 HA'), np.str_('2 HA H'), np.str_('2 HA HA'), np.str_('2 HA L'), np.str_('2 X'), np.str_('2 X X'), np.str_('3'), np.str_('3 H'), np.str_('3 HA'), np.str_('W'), np.str_('W HA'), np.str_('W X')]
# Not setting metadata
# 439 matching events found
# No baseline correction applied
# 0 projection items activated
# Creating RawArray with float64 data, n_channels=7, n_times=1155000
#     Range : 0 ... 1154999 =      0.000 ...  4619.996 secs
# Ready.
# Used Annotations descriptions: [np.str_('1'), np.str_('1 CA'), np.str_('1 CAA'), np.str_('1 CAA CAA L'), np.str_('1 X'), np.str_('2'), np.str_('2 CA'), np.str_('2 CAA'), np.str_('2 H'), np.str_('2 HA'), np.str_('2 X'), np.str_('3 H'), np.str_('W'), np.str_('W CA'), np.str_('W CAA'), np.str_('W CAA L'), np.str_('W H'), np.str_('W HA'), np.str_('W X')]
# Not setting metadata
# 154 matching events found
# No baseline correction applied
# 0 projection items activated

# %%
epoch=mne.concatenate_epochs(all_epochs)
# Out:
# Using data from preloaded Raw for 240 events and 7500 original time points ...
# Using data from preloaded Raw for 360 events and 7500 original time points ...
# Using data from preloaded Raw for 360 events and 7500 original time points ...
# C:\Users\piotr\AppData\Local\Temp\ipykernel_4496\1324350247.py:1: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   epoch=mne.concatenate_epochs(all_epochs)
# Using data from preloaded Raw for 270 events and 7500 original time points ...
# Using data from preloaded Raw for 720 events and 7500 original time points ...
# Using data from preloaded Raw for 720 events and 7500 original time points ...
# Using data from preloaded Raw for 714 events and 7500 original time points ...
# Using data from preloaded Raw for 694 events and 7500 original time points ...
# Using data from preloaded Raw for 640 events and 7500 original time points ...
# Using data from preloaded Raw for 698 events and 7500 original time points ...
# Using data from preloaded Raw for 780 events and 7500 original time points ...
# Using data from preloaded Raw for 760 events and 7500 original time points ...
# Using data from preloaded Raw for 760 events and 7500 original time points ...
# Using data from preloaded Raw for 458 events and 7500 original time points ...
# Using data from preloaded Raw for 710 events and 7500 original time points ...
# Using data from preloaded Raw for 720 events and 7500 original time points ...
# Using data from preloaded Raw for 439 events and 7500 original time points ...
# Using data from preloaded Raw for 154 events and 7500 original time points ...
# Not setting metadata
# 10197 matching events found
# No baseline correction applied

# %%
def eeg_power_band(epochs):
    """EEG relative power band feature extraction.

    This function takes an ``mne.Epochs`` object and creates EEG features based
    on relative power in specific frequency bands that are compatible with
    scikit-learn.

    Parameters
    ----------
    epochs : Epochs
        The data.

    Returns
    -------
    X : numpy array of shape [n_samples, 5 * n_channels]
        Transformed data.
    """
    # specific frequency bands
    FREQ_BANDS = {
        "delta": [0.5, 4.5],
        "theta": [4.5, 8.5],
        "alpha": [8.5, 11.5],
        "sigma": [11.5, 15.5],
        "beta": [15.5, 30],
    }

    spectrum = epochs.compute_psd(picks="eeg", fmin=0.5, fmax=30.0)
    psds, freqs = spectrum.get_data(return_freqs=True)
    # Normalize the PSDs
    psds /= np.sum(psds, axis=-1, keepdims=True)

    X = []
    for fmin, fmax in FREQ_BANDS.values():
        psds_band = psds[:, :, (freqs >= fmin) & (freqs < fmax)].mean(axis=-1)
        X.append(psds_band.reshape(len(psds), -1))

    return np.concatenate(X, axis=1)

# %%
pipe = make_pipeline(
    RandomForestClassifier(n_estimators=100, random_state=42),
)

# Train
y= epoch.events[:, 2]
cross_val_score(pipe,epoch,y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 7
#       5 # Train
#       6 y= epoch.events[:, 2]
# ----> 7 cross_val_score(pipe,epoch,y)
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:684, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     681 # To ensure multimetric format is not supported
#     682 scorer = check_scoring(estimator, scoring=scoring)
# --> 684 cv_results = cross_validate(
#     685     estimator=estimator,
#     686     X=X,
#     687     y=y,
#     688     groups=groups,
#     689     scoring={"score": scorer},
#     690     cv=cv,
#     691     n_jobs=n_jobs,
#     692     verbose=verbose,
#     693     params=params,
#     694     pre_dispatch=pre_dispatch,
#     695     error_score=error_score,
#     696 )
#     697 return cv_results["test_score"]
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:411, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     408 # We clone the estimator to make sure that all the folds are
#     409 # independent, and that it is pickle-able.
#     410 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 411 results = parallel(
#     412     delayed(_fit_and_score)(
#     413         clone(estimator),
#     414         X,
#     415         y,
#     416         scorer=scorers,
#     417         train=train,
#     418         test=test,
#     419         verbose=verbose,
#     420         parameters=None,
#     421         fit_params=routed_params.estimator.fit,
#     422         score_params=routed_params.scorer.score,
#     423         return_train_score=return_train_score,
#     424         return_times=True,
#     425         return_estimator=return_estimator,
#     426         error_score=error_score,
#     427     )
#     428     for train, test in indices
#     429 )
#     431 _warn_or_raise_about_fit_failures(results, error_score)
#     433 # For callable scoring, the return type is only know after calling. If the
#     434 # return type is a dictionary, the error scores can now be inserted with
#     435 # the correct key.
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:858, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     854     estimator = estimator.set_params(**clone(parameters, safe=False))
#     856 start_time = time.time()
# --> 858 X_train, y_train = _safe_split(estimator, X, y, train)
#     859 X_test, y_test = _safe_split(estimator, X, y, test, train)
#     861 result = {}
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\sklearn\utils\metaestimators.py:156, in _safe_split(estimator, X, y, indices, train_indices)
#     154         X_subset = X[np.ix_(indices, train_indices)]
#     155 else:
# --> 156     X_subset = _safe_indexing(X, indices)
#     158 if y is not None:
#     159     y_subset = _safe_indexing(y, indices)
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\sklearn\utils\_indexing.py:272, in _safe_indexing(X, indices, axis)
#     270     return _array_indexing(X, indices, indices_dtype, axis=axis)
#     271 else:
# --> 272     return _list_indexing(X, indices, indices_dtype)
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\sklearn\utils\_indexing.py:63, in _list_indexing(X, key, key_dtype)
#      61     return list(compress(X, key))
#      62 # key is a integer array-like of key
# ---> 63 return [X[idx] for idx in key]
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\mne\utils\mixin.py:148, in GetEpochsMixin.__getitem__(self, item)
#      79 def __getitem__(
#      80     self: Self,
#      81     item,
#      82 ) -> Self:
#      83     """Return an Epochs object with a copied subset of epochs.
#      84
#      85     Parameters
#    (...)
#     146        .. versionadded:: 0.16
#     147     """
# --> 148     return self._getitem(item)
#
# File ~\anaconda_projects\anaconda3\Lib\site-packages\mne\utils\mixin.py:247, in GetEpochsMixin._getitem(***failed resolving arguments***)
#     243     inst._data = np.require(inst._data[select], requirements=["O"])
#     244 if drop_event_id:
#     245     # update event id to reflect new content of inst
#     246     inst.event_id = {
# --> 247         k: v for k, v in inst.event_id.items() if v in inst.events[:, 2]
#     248     }
#     250 if return_indices:
#     251     return inst, select
#
# KeyboardInterrupt:

# %%
X_data=eeg_power_band(epoch)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows

# %%
pipe.fit(X_data,y)
# Out:
# Pipeline(steps=[('randomforestclassifier',
#                  RandomForestClassifier(random_state=42))])

# %%
np.mean(cross_val_score(pipe,X_data,y))
# Out:
# np.float64(0.6196812643645001)

# %%
selected_funcs = {"pow_freq_bands"}
data=epoch.get_data()
y_data = epoch.events[:, 2]
X_data = extract_features(data, epoch.info['sfreq'], selected_funcs)

# %%
np.mean(cross_val_score(pipe,X_data,y_data))
# Out:
# np.float64(0.5474051582378906)
